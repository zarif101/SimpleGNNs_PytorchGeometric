# %%
from torch_geometric.datasets import MNISTSuperpixels
from torch_geometric.transforms import NormalizeFeatures

# %%
dataset = MNISTSuperpixels('mnist_data/',NormalizeFeatures())

# %%
print('There are this many graphs (images) in the dataset: '+str(len(dataset)))
# Out:
# There are this many graphs (images) in the dataset: 60000

# %%
dataset[2].x.shape
# Out:
# torch.Size([75, 1])

# %%
dataset[2].edge_index
# Out:
# tensor([[ 0,  0,  0,  ..., 74, 74, 74],
#         [ 0,  3,  4,  ..., 65, 66, 68]])

# %%
dataset = dataset.shuffle()
train_dataset = dataset[:50000]
test_dataset = dataset[50000:]

# %%
from torch_geometric.data import DataLoader

# %%
test_loader = DataLoader(test_dataset,batch_size=64,shuffle=True)
train_loader = DataLoader(train_dataset,batch_size=64,shuffle=True)

# %%
for step,data in enumerate(train_loader):
    print(data[0].y)
# Out:
# tensor([0])
# tensor([9])
# tensor([4])
# tensor([8])
# tensor([7])
# tensor([2])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([1])
# tensor([1])
# tensor([4])
# tensor([3])
# tensor([6])
# tensor([2])
# tensor([4])
# tensor([8])
# tensor([7])
# tensor([7])
# tensor([0])
# tensor([5])
# tensor([7])
# tensor([9])
# tensor([2])
# tensor([8])
# tensor([6])
# tensor([1])
# tensor([5])
# tensor([9])
# tensor([3])
# tensor([6])
# tensor([4])
# tensor([4])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([5])
# tensor([6])
# tensor([1])
# tensor([7])
# tensor([3])
# tensor([0])
# tensor([6])
# tensor([8])
# tensor([8])
# tensor([5])
# tensor([5])
# tensor([5])
# tensor([7])
# tensor([1])
# tensor([6])
# tensor([2])
# tensor([4])
# tensor([3])
# tensor([4])
# tensor([4])
# tensor([9])
# tensor([5])
# tensor([1])
# tensor([6])
# tensor([5])
# tensor([8])
# tensor([1])
# tensor([4])
# tensor([8])
# tensor([6])
# tensor([0])
# tensor([1])
# tensor([6])
# tensor([5])
# tensor([7])
# tensor([5])
# tensor([3])
# tensor([3])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([8])
# tensor([6])
# tensor([8])
# tensor([6])
# tensor([8])
# tensor([9])
# tensor([3])
# tensor([5])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([0])
# tensor([7])
# tensor([9])
# tensor([0])
# tensor([6])
# tensor([5])
# tensor([5])
# tensor([2])
# tensor([7])
# tensor([1])
# tensor([2])
# tensor([8])
# tensor([1])
# tensor([4])
# tensor([1])
# tensor([6])
# tensor([6])
# tensor([6])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([4])
# tensor([6])
# tensor([7])
# tensor([8])
# tensor([8])
# tensor([4])
# tensor([0])
# tensor([0])
# tensor([5])
# tensor([9])
# tensor([3])
# tensor([1])
# tensor([7])
# tensor([3])
# tensor([7])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([5])
# tensor([6])
# tensor([9])
# tensor([8])
# tensor([1])
# tensor([4])
# tensor([1])
# tensor([7])
# tensor([6])
# tensor([7])
# tensor([7])
# tensor([3])
# tensor([4])
# tensor([7])
# tensor([9])
# tensor([9])
# tensor([8])
# tensor([3])
# tensor([3])
# tensor([2])
# tensor([5])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([6])
# tensor([5])
# tensor([8])
# tensor([5])
# tensor([1])
# tensor([1])
# tensor([8])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([7])
# tensor([6])
# tensor([6])
# tensor([9])
# tensor([8])
# tensor([6])
# tensor([1])
# tensor([7])
# tensor([3])
# tensor([5])
# tensor([6])
# tensor([6])
# tensor([9])
# tensor([7])
# tensor([0])
# tensor([1])
# tensor([5])
# tensor([1])
# tensor([6])
# tensor([1])
# tensor([6])
# tensor([3])
# tensor([5])
# tensor([9])
# tensor([1])
# tensor([8])
# tensor([1])
# tensor([6])
# tensor([7])
# tensor([8])
# tensor([2])
# tensor([1])
# tensor([2])
# tensor([4])
# tensor([4])
# tensor([1])
# tensor([9])
# tensor([3])
# tensor([8])
# tensor([6])
# tensor([9])
# tensor([7])
# tensor([0])
# tensor([7])
# tensor([5])
# tensor([9])
# tensor([4])
# tensor([8])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([6])
# tensor([4])
# tensor([8])
# tensor([3])
# tensor([1])
# tensor([4])
# tensor([8])
# tensor([6])
# tensor([0])
# tensor([8])
# tensor([3])
# tensor([4])
# tensor([5])
# tensor([8])
# tensor([2])
# tensor([5])
# tensor([5])
# tensor([5])
# tensor([9])
# tensor([7])
# tensor([5])
# tensor([8])
# tensor([6])
# tensor([5])
# tensor([6])
# tensor([0])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([1])
# tensor([8])
# tensor([2])
# tensor([6])
# tensor([8])
# tensor([7])
# tensor([6])
# tensor([6])
# tensor([3])
# tensor([9])
# tensor([6])
# tensor([3])
# tensor([9])
# tensor([4])
# tensor([4])
# tensor([1])
# tensor([7])
# tensor([1])
# tensor([2])
# tensor([6])
# tensor([9])
# tensor([8])
# tensor([8])
# tensor([6])
# tensor([9])
# tensor([4])
# tensor([3])
# tensor([2])
# tensor([3])
# tensor([3])
# tensor([2])
# tensor([3])
# tensor([5])
# tensor([4])
# tensor([8])
# tensor([0])
# tensor([9])
# tensor([0])
# tensor([5])
# tensor([0])
# tensor([7])
# tensor([5])
# tensor([8])
# tensor([5])
# tensor([0])
# tensor([1])
# tensor([5])
# tensor([8])
# tensor([6])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([3])
# tensor([0])
# tensor([0])
# tensor([9])
# tensor([5])
# tensor([5])
# tensor([6])
# tensor([1])
# tensor([1])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([3])
# tensor([3])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([3])
# tensor([7])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([2])
# tensor([0])
# tensor([9])
# tensor([3])
# tensor([4])
# tensor([7])
# tensor([5])
# tensor([5])
# tensor([4])
# tensor([7])
# tensor([8])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([6])
# tensor([1])
# tensor([8])
# tensor([7])
# tensor([7])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([7])
# tensor([7])
# tensor([2])
# tensor([6])
# tensor([7])
# tensor([8])
# tensor([4])
# tensor([1])
# tensor([7])
# tensor([6])
# tensor([1])
# tensor([5])
# tensor([8])
# tensor([0])
# tensor([6])
# tensor([1])
# tensor([4])
# tensor([5])
# tensor([6])
# tensor([2])
# tensor([9])
# tensor([5])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([0])
# tensor([9])
# tensor([5])
# tensor([2])
# tensor([5])
# tensor([5])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([4])
# tensor([7])
# tensor([3])
# tensor([6])
# tensor([0])
# tensor([3])
# tensor([6])
# tensor([7])
# tensor([6])
# tensor([5])
# tensor([9])
# tensor([0])
# tensor([0])
# tensor([4])
# tensor([7])
# tensor([6])
# tensor([8])
# tensor([0])
# tensor([6])
# tensor([8])
# tensor([8])
# tensor([6])
# tensor([1])
# tensor([9])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([2])
# tensor([5])
# tensor([4])
# tensor([7])
# tensor([2])
# tensor([1])
# tensor([6])
# tensor([3])
# tensor([1])
# tensor([6])
# tensor([9])
# tensor([7])
# tensor([2])
# tensor([4])
# tensor([6])
# tensor([1])
# tensor([5])
# tensor([8])
# tensor([5])
# tensor([4])
# tensor([7])
# tensor([0])
# tensor([9])
# tensor([1])
# tensor([9])
# tensor([1])
# tensor([3])
# tensor([8])
# tensor([7])
# tensor([7])
# tensor([9])
# tensor([1])
# tensor([4])
# tensor([9])
# tensor([9])
# tensor([1])
# tensor([1])
# tensor([4])
# tensor([1])
# tensor([1])
# tensor([5])
# tensor([4])
# tensor([3])
# tensor([4])
# tensor([3])
# tensor([5])
# tensor([8])
# tensor([8])
# tensor([2])
# tensor([8])
# tensor([4])
# tensor([3])
# tensor([9])
# tensor([6])
# tensor([5])
# tensor([4])
# tensor([6])
# tensor([0])
# tensor([0])
# tensor([9])
# tensor([7])
# tensor([3])
# tensor([2])
# tensor([6])
# tensor([9])
# tensor([5])
# tensor([0])
# tensor([5])
# tensor([9])
# tensor([0])
# tensor([9])
# tensor([7])
# tensor([4])
# tensor([3])
# tensor([1])
# tensor([8])
# tensor([5])
# tensor([3])
# tensor([4])
# tensor([1])
# tensor([6])
# tensor([3])
# tensor([6])
# tensor([0])
# tensor([0])
# tensor([7])
# tensor([3])
# tensor([4])
# tensor([3])
# tensor([2])
# tensor([3])
# tensor([1])
# tensor([7])
# tensor([0])
# tensor([9])
# tensor([9])
# tensor([4])
# tensor([1])
# tensor([4])
# tensor([0])
# tensor([5])
# tensor([4])
# tensor([7])
# tensor([1])
# tensor([6])
# tensor([4])
# tensor([2])
# tensor([3])
# tensor([4])
# tensor([8])
# tensor([4])
# tensor([7])
# tensor([1])
# tensor([7])
# tensor([2])
# tensor([0])
# tensor([4])
# tensor([2])
# tensor([6])
# tensor([7])
# tensor([4])
# tensor([0])
# tensor([1])
# tensor([2])
# tensor([2])
# tensor([3])
# tensor([7])
# tensor([1])
# tensor([6])
# tensor([8])
# tensor([0])
# tensor([5])
# tensor([1])
# tensor([4])
# tensor([7])
# tensor([6])
# tensor([4])
# tensor([7])
# tensor([6])
# tensor([3])
# tensor([4])
# tensor([9])
# tensor([3])
# tensor([3])
# tensor([7])
# tensor([5])
# tensor([7])
# tensor([2])
# tensor([5])
# tensor([2])
# tensor([1])
# tensor([0])
# tensor([9])
# tensor([2])
# tensor([2])
# tensor([7])
# tensor([7])
# tensor([9])
# tensor([3])
# tensor([0])
# tensor([7])
# tensor([7])
# tensor([1])
# tensor([1])
# tensor([6])
# tensor([8])
# tensor([1])
# tensor([3])
# tensor([8])
# tensor([1])
# tensor([7])
# tensor([1])
# tensor([7])
# tensor([5])
# tensor([3])
# tensor([9])
# tensor([7])
# tensor([1])
# tensor([2])
# tensor([3])
# tensor([6])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([9])
# tensor([4])
# tensor([0])
# tensor([7])
# tensor([9])
# tensor([0])
# tensor([5])
# tensor([4])
# tensor([2])
# tensor([6])
# tensor([1])
# tensor([8])
# tensor([1])
# tensor([9])
# tensor([3])
# tensor([8])
# tensor([8])
# tensor([9])
# tensor([0])
# tensor([4])
# tensor([1])
# tensor([7])
# tensor([7])
# tensor([8])
# tensor([7])
# tensor([0])
# tensor([9])
# tensor([1])
# tensor([0])
# tensor([9])
# tensor([7])
# tensor([4])
# tensor([6])
# tensor([8])
# tensor([3])
# tensor([3])
# tensor([2])
# tensor([0])
# tensor([0])
# tensor([6])
# tensor([3])
# tensor([7])
# tensor([4])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([6])
# tensor([4])
# tensor([0])
# tensor([5])
# tensor([2])
# tensor([0])
# tensor([0])
# tensor([9])
# tensor([3])
# tensor([2])
# tensor([3])
# tensor([7])
# tensor([9])
# tensor([3])
# tensor([8])
# tensor([6])
# tensor([1])
# tensor([1])
# tensor([9])
# tensor([0])
# tensor([7])
# tensor([1])
# tensor([1])
# tensor([8])
# tensor([2])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([5])
# tensor([8])
# tensor([2])
# tensor([6])
# tensor([6])
# tensor([8])
# tensor([4])
# tensor([1])
# tensor([9])
# tensor([5])
# tensor([9])
# tensor([1])
# tensor([8])
# tensor([4])
# tensor([1])
# tensor([6])
# tensor([5])
# tensor([9])
# tensor([3])
# tensor([2])
# tensor([8])
# tensor([7])
# tensor([0])
# tensor([6])
# tensor([0])
# tensor([6])
# tensor([3])
# tensor([1])
# tensor([8])
# tensor([3])
# tensor([8])
# tensor([0])
# tensor([7])
# tensor([6])
# tensor([1])
# tensor([0])
# tensor([2])
# tensor([7])
# tensor([1])
# tensor([1])
# tensor([2])
# tensor([6])
# tensor([6])
# tensor([7])
# tensor([0])
# tensor([5])
# tensor([8])
# tensor([5])
# tensor([5])
# tensor([9])
# tensor([0])
# tensor([8])
# tensor([6])
# tensor([7])
# tensor([6])
# tensor([1])
# tensor([7])
# tensor([2])
# tensor([3])
# tensor([4])
# tensor([4])
# tensor([1])
# tensor([6])
# tensor([9])
# tensor([9])
# tensor([9])
# tensor([8])
# tensor([9])
# tensor([3])
# tensor([3])
# tensor([9])
# tensor([9])
# tensor([9])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([2])
# tensor([4])
# tensor([8])
# tensor([7])
# tensor([5])
# tensor([2])
# tensor([2])
# tensor([9])
# tensor([5])
# tensor([0])
# tensor([6])
# tensor([4])
# tensor([6])
# tensor([6])
# tensor([9])
# tensor([3])
# tensor([7])
# tensor([8])
# tensor([4])
# tensor([1])
# tensor([1])
# tensor([2])
# tensor([7])
# tensor([8])
# tensor([9])
# tensor([6])
# tensor([7])
# tensor([0])
# tensor([3])
# tensor([2])
# tensor([3])
# tensor([0])
# tensor([2])
# tensor([1])
# tensor([6])
# tensor([7])
# tensor([5])

# %%
### Model time

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv,global_mean_pool

class Model(nn.Module):
    def __init__(self,hidden_channels):
        super(Model,self).__init__()
        self.conv1 = GCNConv(1,16)
        self.conv2 = GCNConv(16,16)
        self.conv3 = GCNConv(16,16)
        self.linear = nn.Linear(16,10)
    
    def forward(self,x,edge_index,batch):
        x = self.conv1(x,edge_index)
        x = x.relu()
        x = self.conv2(x,edge_index)
        x = x.relu()
        x = self.conv3(x,edge_index)
        
        x = global_mean_pool(x,batch)
      #  print(x.shape)
        #print(x[0])
        #print(x[0].shape)
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.linear(x)
        return x
    def get_graph_embedding(self,x,edge_index,batch):
        x = self.conv1(x,edge_index)
        x = x.relu()
        x = self.conv2(x,edge_index)
        x = x.relu()
        x = self.conv3(x,edge_index)
        
        x = global_mean_pool(x,batch)
        return x

# %%
model = Model(16)

# IF YOU ARE USING GPU
device = torch.device('cuda')
model = model.to(device)
###

num_epochs = 50
optimizer = torch.optim.Adam(model.parameters())
criterion = torch.nn.CrossEntropyLoss()

# %%
def train_epoch(gpu=True):
    total_loss_epoch = 0
    for data in train_loader:
        
        # IF YOU ARE USING GPU
        if gpu:
            data = data.to(device)
            
        optimizer.zero_grad()
        output = model(data.x,data.edge_index,data.batch)
        loss = criterion(output,data.y)
        
        loss.backward()
        optimizer.step()
        total_loss_epoch+=loss
       # print(loss)
    return total_loss_epoch/len(train_loader)

def test_epoch(gpu=True):
    correct = 0
    for data in test_loader:
        # IF YOU ARE USING GPU
        if gpu:
            data = data.to(device)
        output = model(data.x,data.edge_index,data.batch)
        preds = output.argmax(dim=1)
        correct += int((preds==data.y).sum())
    return correct/len(test_loader.dataset)

# %%
for epoch in range(num_epochs):
    train_loss = train_epoch()
    test_acc = test_epoch()
    print('Train Loss: '+str(train_loss)+'..Test Acc: '+str(test_acc))
# Out:
# Train Loss: tensor(2.2265, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2252
# Train Loss: tensor(2.0630, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.251
# Train Loss: tensor(2.0264, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2501
# Train Loss: tensor(2.0124, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.254
# Train Loss: tensor(2.0058, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2555
# Train Loss: tensor(2.0023, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2611
# Train Loss: tensor(1.9964, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2609
# Train Loss: tensor(1.9914, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2597
# Train Loss: tensor(1.9868, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2594
# Train Loss: tensor(1.9833, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.263
# Train Loss: tensor(1.9843, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.268
# Train Loss: tensor(1.9794, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2639
# Train Loss: tensor(1.9765, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2652
# Train Loss: tensor(1.9743, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2665
# Train Loss: tensor(1.9692, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.262
# Train Loss: tensor(1.9674, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.271
# Train Loss: tensor(1.9653, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2654
# Train Loss: tensor(1.9628, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2686
# Train Loss: tensor(1.9610, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2677
# Train Loss: tensor(1.9572, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2768
# Train Loss: tensor(1.9527, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2707
# Train Loss: tensor(1.9467, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2681
# Train Loss: tensor(1.9419, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2793
# Train Loss: tensor(1.9359, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2757
# Train Loss: tensor(1.9330, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2771
# Train Loss: tensor(1.9294, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2722
# Train Loss: tensor(1.9236, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2838
# Train Loss: tensor(1.9176, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2796
# Train Loss: tensor(1.9168, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2856
# Train Loss: tensor(1.9120, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2862
# Train Loss: tensor(1.9100, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2833
# Train Loss: tensor(1.9055, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2899
# Train Loss: tensor(1.9007, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2851
# Train Loss: tensor(1.8998, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2912
# Train Loss: tensor(1.8956, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2912
# Train Loss: tensor(1.8916, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.294
# Train Loss: tensor(1.8881, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2958
# Train Loss: tensor(1.8836, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2883
# Train Loss: tensor(1.8797, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.2997
# Train Loss: tensor(1.8740, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.303
# Train Loss: tensor(1.8714, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.3026
# Train Loss: tensor(1.8664, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.3048
# Train Loss: tensor(1.8617, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.3012
# Train Loss: tensor(1.8571, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.3106
# Train Loss: tensor(1.8544, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.3171
# Train Loss: tensor(1.8476, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.3114
# Train Loss: tensor(1.8458, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.3147
# Train Loss: tensor(1.8412, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.3147
# Train Loss: tensor(1.8379, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.3205
# Train Loss: tensor(1.8352, device='cuda:0', grad_fn=<DivBackward0>)..Test Acc: 0.3224
